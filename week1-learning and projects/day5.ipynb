# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://internshala.com/internships/")
ed.links
# Out:
# ['/login/get_google/',
#  '/login/forgot_password',
#  '/registration/student',
#  '/hire-talent',
#  'https://internshala.com/terms',
#  'mailto:complaints@internshala.com',
#  '/internships',
#  '/jobs',
#  'https://trainings.internshala.com/?utm_source=is_web_internshala_ham',
#  'https://trainings.internshala.com/?utm_source=is_web_hamburger#placement-and-job-guarantee-courses',
#  '/contact',
#  '/registration/student',
#  '/hire-talent',
#  '/',
#  '/registration/student',
#  '/internships',
#  'https://internshala.com/internships/work-from-home-internships',
#  'https://internshala.com/internships/internship-in-bangalore',
#  'https://internshala.com/internships/internship-in-delhi',
#  'https://internshala.com/internships/internship-in-hyderabad',
#  'https://internshala.com/internships/internship-in-mumbai',
#  'https://internshala.com/internships/internship-in-chennai',
#  'https://internshala.com/internships/internship-in-pune',
#  'https://internshala.com/internships/internship-in-kolkata',
#  'https://internshala.com/internships/internship-in-jaipur',
#  'https://internshala.com/internships/international-internship',
#  'https://internshala.com/internships/',
#  'https://internshala.com/internships/computer-science-internship',
#  'https://internshala.com/internships/marketing-internship',
#  'https://internshala.com/internships/finance-internship',
#  'https://internshala.com/internships/graphic-design-internship',
#  'https://internshala.com/internships/architecture-internship',
#  'https://internshala.com/internships/mechanical-internship',
#  'https://internshala.com/internships/hr-internship',
#  'https://internshala.com/internships/digital-marketing-internship',
#  'https://internshala.com/internships/law-internship',
#  'https://internshala.com/internships/electronics-internship',
#  'https://internshala.com/internships/content-writing-internship',
#  'https://internshala.com/internships/civil-internship',
#  'https://internshala.com/internships/campus-ambassador-internship?utm_source=header',
#  'https://internshala.com/internships/',
#  'https://internshala.com/internships/engineering-internship',
#  'https://internshala.com/internships/mba-internship',
#  'https://internshala.com/internships/part-time-jobs',
#  'https://internshala.com/internships/humanities-internship',
#  'https://internshala.com/internships/science-internship',
#  'https://internshala.com/internships/ppo-true',
#  'https://internshala.com/internships-for-women/?utm_source=ifw_is_dropdown',
#  'https://internshala.com/internships/',
#  'https://internshala.com/internships-by-category/?utm_source=is_menu_dropdown',
#  'https://internshala.com/internships-by-location/?utm_source=is_menu_dropdown',
#  'https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/data-science-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/human-resource-management-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/digital-marketing-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/electric-vehicles-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/ui-ux-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/product-management-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/financial-modelling-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/supply-chain-logistics-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/banking-sales-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/software-testing-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown',
#  'https://trainings.internshala.com/?utm_source=is_web_internshala-menu-dropdown1',
#  'https://trainings.internshala.com/web-development-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/python-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/digital-marketing-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/machine-learning-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/excel-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/autocad-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/data-science-beginner-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/c-plus-plus-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/?utm_source=is_web_header_view_all',
#  'https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/data-science-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/human-resource-management-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/digital-marketing-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/ui-ux-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/product-management-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/financial-modelling-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/supply-chain-logistics-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/banking-sales-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  'https://trainings.internshala.com/software-testing-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown',
#  '/jobs?utm_source=is_header',
#  'https://internshala.com/jobs/work-from-home/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-delhi/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-mumbai/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-bangalore/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-hyderabad/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-kolkata/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-chennai/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-pune/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/jobs-in-jaipur/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs//?utm_source=is_menu_dropdown',
#  'https://internshala.com/fresher-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/marketing-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/content-writing-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/computer-science-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/finance-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/hr-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/graphic-design-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/data-science-jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs-by-category/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs-by-location/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs-by-designation/?utm_source=is_menu_dropdown',
#  'https://internshala.com/jobs-by-skill/?utm_source=is_menu_dropdown',
#  'https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/data-science-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/human-resource-management-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/digital-marketing-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/ui-ux-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/product-management-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/financial-modelling-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/supply-chain-logistics-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/banking-sales-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://trainings.internshala.com/software-testing-placement-guarantee-course/?utm_source=is_web_job-menu-dropdown',
#  'https://internshala.com/registration/student',
#  'https://internshala.com/hire-talent',
#  '/terms#student',
#  '/login/get_google/?utm_source=modal_signup_search',
#  '/registration/student/?utm_source=modal_signup_search',
#  '/registration/student?utm_source=ifwregistrationcontent ',
#  'mailto:helpdesk@internshala.com',
#  '/registration/student?utm_source=ifwregistrationcontent ',
#  'mailto:helpdesk@internshala.com',
#  'https://internshala.com/',
#  'https://internshala.com/internships/',
#  '/registration/student',
#  '/registration/student',
#  '/internship/detail/sales-internship-in-bhopal-at-utm-delight1749037411',
#  '/internship/detail/digital-marketing-internship-in-multiple-locations-at-pinacle-web-india1749798534',
#  '/internship/detail/php-development-internship-in-multiple-locations-at-fyntune-solution-private-limited1749187653',
#  '/internship/detail/human-resources-hr-internship-in-ludhiana-at-precision-metallurgy-india-private-limited1749712408',
#  '/internship/detail/academic-counselor-internship-in-multiple-locations-at-yes-germany1749633613',
#  '/internship/detail/business-development-sales-internship-in-multiple-locations-at-zapkey-technologies-private-limited1749642823',
#  '/internship/detail/digital-marketing-seo-internship-in-udaipur-at-icubes1748420023',
#  '/internship/detail/artificial-intelligence-ai-internship-in-indore-at-raletta-technology-private-limited1749531248',
#  '/internship/detail/ui-ux-design-internship-in-jaipur-at-orufy-technologies-private-limited1749037663',
#  '/internship/detail/video-editing-making-internship-in-multiple-locations-at-digivibrant-techsolutions-private-limited1748004286',
#  'https://trainings.internshala.com/?utm_source=is_web_internship_native_ad_2nd_card',
#  '/internship/detail/digital-ad-sales-internship-in-noida-at-times-internet1749814936',
#  '/internship/detail/business-development-sales-internship-in-thane-at-ilux-electricals1749643234',
#  '/internship/detail/work-from-home-marketing-internship-at-edlernity-tech-opc-private-limited1749832785',
#  '/internship/detail/product-marketing-internship-in-bangalore-at-cloudnine-hospital1749824432',
#  '/internship/detail/full-stack-development-internship-in-bangalore-at-angelone1749823821',
#  '/internship/detail/creative-design-internship-in-mumbai-at-waaree-energies-limited1749811663',
#  '/internship/detail/search-engine-optimization-seo-internship-in-bangalore-at-nobroker1749810142',
#  '/internship/detail/work-from-home-stock-market-learning-outreach-internship-at-focus-wise-solution1749816827',
#  '/internship/detail/part-time-data-entry-internship-in-gurgaon-at-intertek-india-private-limited1749805029',
#  '/internship/detail/video-editing-making-internship-in-bangalore-at-letstransport1749808096',
#  '/internship/detail/database-building-management-internship-in-noida-at-times-internet-economic-times1749795492',
#  '/internship/detail/work-from-home-video-editing-making-internship-at-dcc1749794037',
#  '/internship/detail/hotel-managementchef-internship-in-mumbai-at-theobroma-foods-private-limited1749735667',
#  '/internship/detail/marketing-internship-in-mumbai-at-ashley1749734880',
#  '/internship/detail/part-time-accounts-internship-in-chennai-at-sindoori-management-solutions-pvt-ltd1749730741',
#  '/internship/detail/part-time-field-sales-internship-in-bangalore-at-nobroker1749730015',
#  '/internship/detail/performance-marketing-internship-in-mumbai-at-zee-entertainment-enterprises-limited1749727604',
#  '/internship/detail/work-from-home-part-time-business-development-sales-manager-internship-at-yana1749725122',
#  '/internship/detail/recruitment-internship-in-multiple-locations-at-pine-labs1749713551',
#  '/internship/detail/video-editing-making-internship-in-noida-at-times-internet1749706541',
#  '/internship/detail/part-time-company-secretary-cs-internship-in-bangalore-at-motherhood-hospital1749643827',
#  '/internship/detail/part-time-sales-and-marketing-internship-in-bangalore-at-ankit-mishra1749646576',
#  '/internship/detail/sales-consultant-internship-in-kolkata-at-webvio-technologies1749641978',
#  '/internship/detail/work-from-home-financial-stock-market-research-internship-at-focus-wise-solution1749640020',
#  '/internship/detail/legal-research-internship-in-gurgaon-at-collegedekhocom1749637987',
#  '/internship/detail/law-legal-internship-in-mumbai-at-air-india-sats-airport-services-private-limited1749622587',
#  '/internship/detail/inside-sales-internship-in-bangalore-at-unacademy-sorting-hat-technologies-private-limited1749628887',
#  '/internship/detail/human-resources-hr-internship-in-mumbai-at-angelone1749627846',
#  '/internship/detail/sales-internship-in-mumbai-at-halma1749624507',
#  '/internship/detail/fashion-consultant-internship-in-multiple-locations-at-bestseller1749559657',
#  '/internship/detail/human-resources-hr-internship-in-mumbai-at-audi-mumbai-west1749557581',
#  '/internship/detail/marketing-internship-in-bangalore-at-edlernity-tech-opc-private-limited1749549787',
#  '/internship/detail/video-editing-making-internship-in-bangalore-at-zeta-india1749541693',
#  '/internship/detail/finance-internship-in-gurgaon-at-ireed-academy-india-private-limited1749537609',
#  '/internship/detail/network-engineering-internship-in-chennai-at-caratlane-trading-private-limited1749535313',
#  '/internship/detail/corporate-booking-executive-oncall-internship-in-mumbai-at-mahindra-logistics-limited1749476423',
#  '/internship/detail/hris-intern-internship-in-mumbai-at-mahindra-logistics-limited1749475853',
#  '/internship/detail/operations-executive-b2c-internship-in-mumbai-at-mahindra-logistics-limited1749475428',
#  '/internship/detail/operations-executive-central-initiatives-internship-in-mumbai-at-mahindra-logistics-limited1749474429',
#  '/internship/detail/inside-sales-internship-in-bangalore-at-unacademy-sorting-hat-technologies-private-limited1749466282',
#  '/internship/page-1',
#  '/internship/page-2',
#  '/internship/page-3',
#  '/internship/page-4',
#  '/internship/page-5',
#  '/internship/page-6',
#  '#',
#  '/internship/page-194',
#  'internship/page-2',
#  '/internship/page-1',
#  '/internship/page-2',
#  '/internship/page-3',
#  '/internship/page-4',
#  '#',
#  '/internship/page-194',
#  'internship/page-2',
#  'https://internshala.com/internships/marketing-internship/',
#  'https://internshala.com/internships/content-writing-internship/',
#  'https://internshala.com/internships/computer-science-internship/',
#  'https://internshala.com/internships/digital-marketing-internship/',
#  'https://internshala.com/internships/data-science-internship/',
#  'https://internshala.com/internships/hr-internship/',
#  'https://internshala.com/jobs/marketing-internships/work-from-home/',
#  'https://internshala.com/jobs/content-writing-internships/work-from-home/',
#  'https://internshala.com/jobs/computer-science-internships/work-from-home/',
#  'https://internshala.com/jobs/digital-marketing-internships/work-from-home/',
#  'https://internshala.com/jobs/data-science-internships/work-from-home/',
#  'https://internshala.com/jobs/hr-internships/work-from-home/',
#  'https://internshala.com/internships/internship-in-delhi/',
#  'https://internshala.com/internships/internship-in-mumbai/',
#  'https://internshala.com/internships/internship-in-bangalore/',
#  'https://internshala.com/internships/internship-in-hyderabad/',
#  'https://internshala.com/internships/internship-in-kolkata/',
#  'https://internshala.com/internships/internship-in-chennai/',
#  'https://internshala.com/internships/work-from-home-internships-in-delhi/',
#  'https://internshala.com/internships/work-from-home-internships-in-mumbai/',
#  'https://internshala.com/internships/work-from-home-internships-in-bangalore/',
#  'https://internshala.com/internships/work-from-home-internships-in-hyderabad/',
#  'https://internshala.com/internships/work-from-home-internships-in-kolkata/',
#  'https://internshala.com/internships/work-from-home-internships-in-chennai/',
#  'https://internshala.com/jobs/marketing-jobs/',
#  'https://internshala.com/jobs/content-writing-jobs/',
#  'https://internshala.com/jobs/computer-science-jobs/',
#  'https://internshala.com/jobs/digital-marketing-jobs/',
#  'https://internshala.com/jobs/data-science-jobs/',
#  'https://internshala.com/jobs/hr-jobs/',
#  'https://internshala.com/jobs/marketing-jobs/work-from-home/',
#  'https://internshala.com/jobs/content-writing-jobs/work-from-home/',
#  'https://internshala.com/jobs/computer-science-jobs/work-from-home/',
#  'https://internshala.com/jobs/digital-marketing-jobs/work-from-home/',
#  'https://internshala.com/jobs/data-science-jobs/work-from-home/',
#  'https://internshala.com/jobs/hr-jobs/work-from-home/',
#  'https://internshala.com/jobs/jobs-in-delhi/',
#  'https://internshala.com/jobs/jobs-in-mumbai/',
#  'https://internshala.com/jobs/jobs-in-bangalore/',
#  'https://internshala.com/jobs/jobs-in-hyderabad/',
#  'https://internshala.com/jobs/jobs-in-kolkata/',
#  'https://internshala.com/jobs/jobs-in-chennai/',
#  'https://internshala.com/jobs/jobs-in-delhi/work-from-home/',
#  'https://internshala.com/jobs/jobs-in-mumbai/work-from-home/',
#  'https://internshala.com/jobs/jobs-in-bangalore/work-from-home/',
#  'https://internshala.com/jobs/jobs-in-hyderabad/work-from-home/',
#  'https://internshala.com/jobs/jobs-in-kolkata/work-from-home/',
#  'https://internshala.com/jobs/jobs-in-chennai/work-from-home/',
#  '/company/times-internet-1719682373/careers/?utm_source=backlink/',
#  '/company/ilux-electricals-1741087868/careers/?utm_source=backlink/',
#  '/company/edlernity-tech-opc-private-limited-1712861530/careers/?utm_source=backlink/',
#  '/company/cloudnine-hospital-1459409423/careers/?utm_source=backlink/',
#  '/company/angelone-1700243795/careers/?utm_source=backlink/',
#  '/company/waaree-energies-limited-1715862854/careers/?utm_source=backlink/',
#  '/company/nobroker-1543218365/careers/?utm_source=backlink/',
#  '/company/focus-wise-solution-1745997996/careers/?utm_source=backlink/',
#  '/company/intertek-india-private-limited-1655881788/careers/?utm_source=backlink/',
#  '/company/letstransport-1599223299/careers/?utm_source=backlink/',
#  '/company/times-internet-economic-times-1660627343/careers/?utm_source=backlink/',
#  '/company/dcc-1684588658/careers/?utm_source=backlink/',
#  'https://internshala.com/jobs/',
#  'https://internshala.com/fresher-jobs/part-time-work-from-home-jobs/',
#  'https://internshala.com/fresher-jobs/part-time-jobs/',
#  'https://internshala.com/jobs/part-time-work-from-home-jobs/',
#  'https://internshala.com/fresher-jobs/work-from-home/',
#  'https://internshala.com/jobs/part-time-jobs/',
#  'https://internshala.com/jobs/work-from-home/',
#  'https://internshala.com/internships/work-from-home-internships/part-time-true/',
#  'https://internshala.com/fresher-jobs/',
#  'https://internshala.com/internships/part-time-jobs/',
#  'https://internshala.com/internships/work-from-home-internships/',
#  'https://internshala.com/internships-for-women/',
#  'https://internshala.com/jobs-for-women/',
#  'https://internshala.com/internships-for-women/work-from-home-internships/',
#  'https://internshala.com/jobs-for-women/work-from-home/',
#  'https://internshala.com/internships-for-women/part-time-jobs/',
#  'https://internshala.com/jobs-for-women/part-time-jobs/',
#  'https://internshala.com/jobs-for-women/part-time-work-from-home/',
#  'https://internshala.com/',
#  'https://internshala.com/internships/',
#  'https://internshala.com/internships/',
#  'https://internshala.com/internships/work-from-home-internships/',
#  'https://internshala.com/internships/part-time-jobs/',
#  'https://trainings.internshala.com/digital-marketing-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/data-science-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/product-management-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/ui-ux-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/human-resource-management-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/banking-sales-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/software-testing-placement-guarantee-course/?utm_source=is_web_faq_search_page/',
#  'https://trainings.internshala.com/web-development-course/',
#  'https://trainings.internshala.com/python-course/',
#  'https://trainings.internshala.com/hacking-course/',
#  'https://trainings.internshala.com/java-course/',
#  'https://trainings.internshala.com/digital-marketing-course/',
#  'https://trainings.internshala.com/data-science-beginner-course/',
#  'https://trainings.internshala.com/tally-course/',
#  'https://trainings.internshala.com/machine-learning-course/',
#  'https://trainings.internshala.com/ui-ux-design-course/',
#  '/internships',
#  '/internships/internship-in-delhi',
#  '/internships/internship-in-bangalore',
#  '/internships/internship-in-hyderabad',
#  '/internships/internship-in-mumbai',
#  '/internships/internship-in-chennai',
#  '/internships/internship-in-gurgaon',
#  '/internships/internship-in-kolkata',
#  '/internships/work-from-home-internships',
#  '/internships-by-location/?utm_source=is_footer',
#  '/internships/computer-science-internship',
#  '/internships/electronics-internship',
#  '/internships/mechanical-internship',
#  '/internships/civil-internship',
#  '/internships/marketing-internship',
#  '/internships/chemical-internship',
#  '/internships/finance-internship',
#  '/internships/summer-research-fellowship-internship',
#  '/internships/campus-ambassador-internship?utm_medium=footer',
#  '/internships-by-category/?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-delhi?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-mumbai?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-bangalore?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-jaipur?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-kolkata?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-hyderabad?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-pune?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-chennai?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-lucknow?utm_source=is_footer',
#  'https://internshala.com/jobs-by-location/?utm_source=is_footer',
#  'https://internshala.com/jobs/marketing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/content-writing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/web-development-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/marketing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/finance-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/digital-marketing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/computer-science-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/graphic-design-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/data-science-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs-by-category/?utm_source=is_footer',
#  'https://trainings.internshala.com/placement-and-job-guarantee-courses/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/data-science-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/human-resource-management-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/digital-marketing-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/ui-ux-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/product-management-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/financial-modelling-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/supply-chain-logistics-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/banking-sales-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/software-testing-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/short-term-courses/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/placement-and-job-guarantee-courses/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/data-science-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/human-resource-management-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/digital-marketing-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/ui-ux-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/product-management-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/financial-modelling-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/supply-chain-logistics-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/banking-sales-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/software-testing-placement-guarantee-course/?utm_source=is_web_is-footer/',
#  'https://trainings.internshala.com/short-term-courses/?utm_source=is_web_is-footer/',
#  'https://internshala.com/jobs-by-category/?utm_source=is_footer',
#  'https://internshala.com/jobs-by-location/?utm_source=is_footer',
#  'https://internshala.com/jobs/?utm_source=is_footer',
#  '/about_us',
#  '/careers',
#  '/hire-talent?utm_source=ISfooter',
#  '/post-job?utm_source=ISfooterHome',
#  'https://blog.internshala.com/internshala-editorials/team-diary/',
#  'https://blog.internshala.com/?utm_source=IS_footer',
#  '/products_services',
#  '/free-job-alerts?utm_source=is_footer',
#  '/terms',
#  '/privacy',
#  '/contact',
#  '/sitemap?utm_source=is_footer',
#  '/college_registration/associate/?utm_source=footer',
#  '/companies/?utm_source=footer',
#  '/resume-maker?utm_source=is_footer',
#  '/jobs-for-women?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-delhi?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-mumbai?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-bangalore?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-jaipur?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-kolkata?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-hyderabad?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-pune?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-chennai?utm_source=is_footer',
#  'https://internshala.com/jobs/jobs-in-lucknow?utm_source=is_footer',
#  'https://internshala.com/jobs-by-location/?utm_source=is_footer',
#  'https://internshala.com/jobs/marketing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/content-writing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/web-development-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/marketing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/finance-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/digital-marketing-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/computer-science-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/graphic-design-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs/data-science-jobs?utm_source=is_footer',
#  'https://internshala.com/jobs-by-category/?utm_source=is_footer',
#  '/about_us',
#  '/careers',
#  '/hire-talent?utm_source=ISfooter',
#  '/post-job?utm_source=ISfooterHome',
#  'https://blog.internshala.com/internshala-editorials/team-diary/',
#  'https://blog.internshala.com/?utm_source=IS_footer',
#  '/products_services',
#  '/free-job-alerts?utm_source=is_footer',
#  '/resume-maker?utm_source=is_footer',
#  '/jobs-for-women?utm_source=is_footer',
#  '/terms',
#  '/privacy',
#  '/contact',
#  '/sitemap?utm_source=is_footer',
#  '/about_us',
#  '/careers',
#  '/hire-talent?utm_source=ISfooter',
#  '/post-job?utm_source=ISfooterHome',
#  'https://blog.internshala.com/internshala-editorials/team-diary/',
#  'https://blog.internshala.com/?utm_source=IS_footer',
#  '/products_services',
#  '/free-job-alerts?utm_source=is_footer',
#  '/terms',
#  '/privacy',
#  '/contact',
#  '/resume-maker?utm_source=is_footer',
#  '/sitemap?utm_source=is_footer',
#  '/college_registration/associate/?utm_source=footer',
#  '/companies/?utm_source=footer',
#  'jobs-for-women?utm_source=is_footer',
#  'https://www.instagram.com/internshala/?utm_source=IS_footer',
#  'https://twitter.com/Internshala?utm_source=IS_footer',
#  'https://www.youtube.com/c/internshalaofficial?utm_source=IS_footer',
#  'https://www.linkedin.com/company/internshala/?utm_source=is-footer',
#  '/?utm_source=bottom_navigaton',
#  '/internships/?utm_source=bottom_navigaton',
#  '/jobs/?utm_source=bottom_navigaton',
#  'https://trainings.internshala.com/?utm_source=is_web_bottom_navigation']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://unstop.com/ - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://unstop.com/legal/privacy-policy

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/mistralai/Magistral-Small-2506',
#  '/openbmb/MiniCPM4-8B',
#  '/echo840/MonkeyOCR',
#  '/deepseek-ai/DeepSeek-R1-0528',
#  '/Qwen/Qwen3-Embedding-0.6B-GGUF',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/ResembleAI/Chatterbox',
#  '/spaces/multimodalart/wan2-1-fast',
#  '/spaces/aisheets/sheets',
#  '/spaces/Agents-MCP-Hackathon/AI-Marketing-Content-Creator',
#  '/spaces',
#  '/datasets/nvidia/Nemotron-Personas',
#  '/datasets/open-thoughts/OpenThoughts3-1.2M',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/institutional/institutional-books-1.0',
#  '/datasets/a-m-team/AM-DeepSeek-R1-0528-Distilled',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord',
#  'https://www.zhihu.com/org/huggingface',
#  'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/blog/chinese-language-blog/wechat.jpg']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'company blog', 'url': 'https://huggingface.co/blog'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'join Discord page', 'url': 'https://huggingface.co/join/discord'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'forum page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# mistralai/Magistral-Small-2506
# Updated
# 3 days ago
# •
# 7.67k
# •
# 378
# openbmb/MiniCPM4-8B
# Updated
# about 18 hours ago
# •
# 4.55k
# •
# 224
# echo840/MonkeyOCR
# Updated
# 1 day ago
# •
# 173
# deepseek-ai/DeepSeek-R1-0528
# Updated
# 15 days ago
# •
# 120k
# •
# 1.96k
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# 5 days ago
# •
# 16.4k
# •
# 348
# Browse 1M+ models
# Spaces
# Running
# 8.01k
# 8.01k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 1.05k
# 1.05k
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Running
# on
# Zero
# 679
# 679
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# 157
# 157
# Sheets
# 🗂
# Convert ideas into structured datasets
# Running
# 131
# 131
# AI Marketing Content Generator
# 🎨
# An AI-powered tool made for content creators and marketers
# Browse 400k+ applications
# Datasets
# nvidia/Nemotron-Personas
# Updated
# 4 days ago
# •
# 5.64k
# •
# 84
# open-thoughts/OpenThoughts3-1.2M
# Updated
# 4 days ago
# •
# 13.7k
# •
# 100
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 22.6k
# •
# 7.92k
# institutional/institutional-books-1.0
# Updated
# 2 days ago
# •
# 869
# •
# 36
# a-m-team/AM-DeepSeek-R1-0528-Distilled
# Updated
# 4 days ago
# •
# 5.47k
# •
# 64
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 765 models
# •
# 3.43k followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.41k followers
# Amazon
# company
# •
# 20 models
# •
# 3.23k followers
# Google
# company
# •
# 999 models
# •
# 16.5k followers
# Intel
# company
# •
# 232 models
# •
# 2.63k followers
# Microsoft
# company
# •
# 390 models
# •
# 12.9k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 296 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,565
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,343
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,306
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,681
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,794
# Fast tokenizers optimized for research & production
# TRL
# 14,163
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,796
# State-of-the-art ML running directly in your browser
# smolagents
# 20,107
# Smol library to build great agents in Python
# PEFT
# 18,760
# Parameter-efficient finetuning for large language models
# Datasets
# 20,267
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,217
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,828
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# about (Sergei)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Sergei
# about
# Follow
# Kalaipriya's profile picture
# AlbertRuan's profile picture
# Renumathi's profile picture
# 5
# 					followers
# ·
# 0 following
# AI & ML interests
# None yet
# Organizations
# None yet
# models
# 0
# None public yet
# datasets
# 0
# None public yet
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# company page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# from $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 409 models
# •
# 28.9k followers
# Shopify
# Enterprise
# company
# •
# 477 followers
# AMD
# Enterprise
# company
# •
# 145 models
# •
# 1.59k followers
# JetBrains
# Enterprise
# company
# •
# 10 models
# •
# 557 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 623 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 110 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 151 followers
# IBM Granite
# Enterprise
# company
# •
# 122 models
# •
# 1.87k followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 428 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 74 followers
# Skywork
# Enterprise
# company
# •
# 42 models
# •
# 723 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 1.05k followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 863 followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.41k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 539 followers
# Arm
# Enterprise
# company
# •
# 215 followers
# Qwen
# Enterprise
# company
# •
# 289 models
# •
# 34.8k followers
# Xsolla
# Enterprise
# company
# •
# 139 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 119 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 70 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 69 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 347 followers
# LinkedIn
# Enterprise
# company
# •
# 62 followers
# JFrog
# Enterprise
# company
# •
# 58 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 47.9k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 302 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 234 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 296 followers
# ServiceNow
# Enterprise
# company
# •
# 510 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 287 followers
# Fidelity Investments
# Enterprise
# company
# •
# 151 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 4 models
# •
# 155 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.44k followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# MiniMax
# Enterprise
# company
# •
# 5 models
# •
# 735 followers
# Liquid AI
# Enterprise
# company
# •
# 201 followers
# Novo Nordisk R&ED
# Enterprise
# company
# •
# 37 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# PRO Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# 10× Private storage capacity
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 8× more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $2.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $2.50
# 2
# 160GB
# $5.00
# 4
# 320GB
# $10.00
# 8
# 640GB
# $20.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# ZeroGPU
# : Get 8× usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Enhance Your Models in 5 Minutes with the Hugging Face Kernel Hub
# By
# drbh
# June 12, 2025
# •
# 21
# Community Articles
# view all
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 4 others
# •
# 2 days ago
# •
# 49
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 7 days ago
# •
# 38
# GRPO for GUI Grounding Done Right
# By
# HelloKKMe
# •
# 3 days ago
# •
# 25
# MCP is at a Tipping Point: Here's Why You Should Care
# By
# fdaudens
# •
# 3 days ago
# •
# 14
# Open Source AI: A Cornerstone of Digital Sovereignty
# By
# frimelle
# and 1 other
# •
# 2 days ago
# •
# 12
# Nemotron-Personas: Improve AI Training With the First Synthetic Personas Dataset Aligned to Real-World Distributions
# By
# nvidia
# and 1 other
# •
# 3 days ago
# •
# 10
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 7 days ago
# •
# 14
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 93
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 610
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 78
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 288
# Sensitivity Aware Mixed Precision Quantization V1
# By
# badaoui
# and 1 other
# •
# about 6 hours ago
# •
# 6
# Tensors
# By
# KeighBee
# •
# 7 days ago
# •
# 6
# Saying Thank You to a LLM Isn't Free — Measuring the Energy Cost of Politeness
# By
# jdelavande
# and 2 others
# •
# 1 day ago
# •
# 6
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 10 days ago
# •
# 65
# Build AI Apps & Super Agents with Masa Data API & Scraper Tools
# By
# MasaFoundation
# •
# 2 days ago
# •
# 5
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 259
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 188
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 152
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 18 days ago
# •
# 44
# Featherless AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 12, 2025
# •
# 33
# Introducing Training Cluster as a Service - a new collaboration with NVIDIA
# By
# jeffboudier
# June 11, 2025
# •
# 15
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 38
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 67
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 128
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 49
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 52
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 41
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 19
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 127
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 33
# nanoVLM: The simplest repository to train your VLM in pure PyTorch
# By
# ariG23498
# May 21, 2025
# •
# 151
# Microsoft and Hugging Face expand collaboration
# By
# jeffboudier
# May 19, 2025
# •
# 21
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 113
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 4 others
# •
# 2 days ago
# •
# 49
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 7 days ago
# •
# 38
# GRPO for GUI Grounding Done Right
# By
# HelloKKMe
# •
# 3 days ago
# •
# 25
# MCP is at a Tipping Point: Here's Why You Should Care
# By
# fdaudens
# •
# 3 days ago
# •
# 14
# Open Source AI: A Cornerstone of Digital Sovereignty
# By
# frimelle
# and 1 other
# •
# 2 days ago
# •
# 12
# Nemotron-Personas: Improve AI Training With the First Synthetic Personas Dataset Aligned to Real-World Distributions
# By
# nvidia
# and 1 other
# •
# 3 days ago
# •
# 10
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 7 days ago
# •
# 14
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 93
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 610
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 78
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 288
# Sensitivity Aware Mixed Precision Quantization V1
# By
# badaoui
# and 1 other
# •
# about 6 hours ago
# •
# 6
# Tensors
# By
# KeighBee
# •
# 7 days ago
# •
# 6
# Saying Thank You to a LLM Isn't Free — Measuring the Energy Cost of Politeness
# By
# jdelavande
# and 2 others
# •
# 1 day ago
# •
# 6
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 10 days ago
# •
# 65
# Build AI Apps & Super Agents with Masa Data API & Scraper Tools
# By
# MasaFoundation
# •
# 2 days ago
# •
# 5
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 259
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 188
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 152
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 18 days ago
# •
# 44
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# forum page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Requirements for Hosting LLM via Inference Endpoints
# Inference Endpoints on the Hub
# 2
# 14
# June 13, 2025
# HuggingFaceModel create fails with no GPU
# Amazon SageMaker
# 1
# 9
# June 13, 2025
# Can a Small LLM Learn to Reason Like a Larger One? Reflection-based Fine-Tuning vs Classical SFT on LLaMA 3.2 (Java CodeGen)
# Research
# 2
# 13
# June 13, 2025
# ASTFeatureExtractor
# Models
# 1
# 4
# June 13, 2025
# Ajay Hinduja Switzerland : How can I integrate a real-time data API into my app?
# Beginners
# 0
# 7
# June 13, 2025
# Best Current voice to voice API
# Research
# 2
# 23
# June 13, 2025
# About runtime error
# Beginners
# 0
# 6
# June 13, 2025
# Replace trained ChatGPT (no coder)
# Beginners
# 2
# 19
# June 13, 2025
# Error: Provider 'featherless-ai' not supported
# Beginners
# 5
# 14
# June 13, 2025
# Comments on Posts get flagged?
# Beginners
# 2
# 22
# June 11, 2025
# 401 Client Error: Unauthorized for url: https://huggingface.co/DeepBeepMeep/Wan2.1
# Beginners
# 1
# 11
# June 12, 2025
# Fast api zero GPU problem
# Beginners
# 1
# 9
# June 12, 2025
# ControlNet SDXL checkpoint
# Beginners
# 2
# 9
# June 13, 2025
# Unable to call google/tapas-large-finetuned-wtq model
# Beginners
# 2
# 15
# June 12, 2025
# Regarding the House Material Change
# Beginners
# 4
# 22
# June 13, 2025
# Chainlit WebSocket Issue on Hugging Face Spaces: Missing websockets in Requirements?
# Spaces
# 4
# 94
# June 12, 2025
# HF auto train dataset load_metric error
# Beginners
# 33
# 86
# June 5, 2025
# Can I ask a question if I have a good idea but can't write programs?
# Beginners
# 41
# 258
# June 3, 2025
# Correct way to load multiple LoRA adapters for inference
# 🤗Transformers
# 4
# 17
# June 11, 2025
# Built a new plot that can visualize 5–7 dimensions in 3D without losing interpretability — introducing Multi-Dimensional Radial Plot (MDRV)
# Research
# 6
# 24
# June 13, 2025
# Error 401 Client Error: Unauthorized for url
# 🤗Hub
# 65
# 102498
# June 12, 2025
# Unable to Upload arXiv Paper to HuggingFace Daily Papers
# 🤗Hub
# 3
# 20
# June 13, 2025
# Testing hugging face in langchain vs code
# Models
# 1
# 10
# June 12, 2025
# Text-to-Sql model keeps missing "<" token
# Intermediate
# 2
# 24
# June 11, 2025
# Hello experts please help on running local DeepSeek-R1-0528-Qwen3-8B
# Beginners
# 2
# 40
# June 10, 2025
# Triskel Data Deterministic Ai
# Beginners
# 5
# 7
# June 12, 2025
# Error fine tuning Donut model using LoRA
# Beginners
# 5
# 35
# June 12, 2025
# API call URL error
# Beginners
# 1
# 9
# June 12, 2025
# Just don't get it: OpenAI API in Open WebUI
# Beginners
# 2
# 12
# June 12, 2025
# Where is the link to Colab?
# Beginners
# 2
# 12
# June 12, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 50.2k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Python
# 146k
# 29.3k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.3k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.3k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.8k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.8k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 547
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 321 repositories
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 29,343
# Apache-2.0
# 6,023
# 499
# (12 issues need help)
# 194
# Updated
# Jun 13, 2025
# pytorch-image-models
# Public
# The largest collection of PyTorch image encoders / backbones. Including train, eval, inference, export scripts, and pretrained weights -- ResNet, ResNeXT, EfficientNet, NFNet, Vision Transformer (ViT), MobileNetV4, MobileNet-V3 & V2, RegNet, DPN, CSPNet, Swin Transformer, MaxViT, CoAtNet, ConvNeXt, and more
# huggingface/pytorch-image-models’s past year of commit activity
# Python
# 34,442
# Apache-2.0
# 4,929
# 52
# (5 issues need help)
# 24
# Updated
# Jun 13, 2025
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# huggingface/transformers’s past year of commit activity
# Python
# 145,565
# Apache-2.0
# 29,332
# 1,047
# (2 issues need help)
# 778
# Updated
# Jun 13, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 14,457
# Apache-2.0
# 1,850
# 247
# 148
# Updated
# Jun 13, 2025
# inference-playground
# Public
# huggingface/inference-playground’s past year of commit activity
# Svelte
# 42
# MIT
# 3
# 0
# 1
# Updated
# Jun 13, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 115
# Apache-2.0
# 13
# 3
# 10
# Updated
# Jun 13, 2025
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# huggingface/datasets’s past year of commit activity
# Python
# 20,267
# Apache-2.0
# 2,847
# 811
# (2 issues need help)
# 97
# Updated
# Jun 13, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,828
# Apache-2.0
# 1,128
# 83
# (4 issues need help)
# 18
# Updated
# Jun 13, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 14,163
# Apache-2.0
# 1,959
# 402
# 78
# Updated
# Jun 13, 2025
# agents-course
# Public
# This repository contains the Hugging Face Agents Course.
# huggingface/agents-course’s past year of commit activity
# MDX
# 19,742
# Apache-2.0
# 1,338
# 56
# (1 issue needs help)
# 19
# Updated
# Jun 13, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 553 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 10h
# Report this post
# Dolphin: new OCR model by
# ByteDance
# with MIT license 🐬
#
# the model first detects element in the layout (table, formula etc) and then parses each element in parallel for generation ⤵️
#
# model and demo is on Hugging Face Hub 🤗 find link in comments
# 703
# 30 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 1d
# Report this post
# So many models released past week in open AI, here’s the weekly picks 🥹
# You can find more models, datasets and demos in the link in comments 💬
#
# 📚 LLMs/Retrieval
# > Qwen released Qwen3-Reranker-4B, a text retriever that it supports 100+ languages ranking #1 on MTEB!
# > Qwen also released Qwen3-Embedding models, new embeddings that come In 600M, 4B & 8B
# > Openbmb released MiniCPM4, new family of efficient LLMs that come in different sizes for end-side devices (OS) they also released an MCP compatible version
# > Homunculus is a 12B hybrid (reasoning/chat) model distilled from Qwen3-235B by Arcee AI (OS)
#
# 🖼️💬 VLMs
# > MonkeyOCR is a new open-source state-of-the-art 3B document parser (OS)
# > Google DeepMind released desktop version of Gemma 3n
# > NVIDIA released Llama-3.1-Nemotron-Nano-VL-8B-V1, new VLM
# > MSFT released an agentic VLM for GUI control GUI-Actor-7B-Qwen2-VL based on Qwen2-VL-7B (OS)
#
# 🤖 VLAs/Robotics
# > RoboBrain2.0-7B is a new VLA with action planning with 7B and 32B sizes (OS)
# > Hugging Face released SmolVLA-Base, new vision language action model (OS)
#
# 🗣️ Audio
# > openaudio-s1-mini is a new text-to-speech model with support for various languages, offers emotional and tone markers by fishaudio
#
# ⏯️ Video Gen
# > ByteDance released ContentV-8B, new video generation model for portraits, scenes, unusual setups and more! (OS)
#
# Which one is your favorite? 👀
# …more
# 148
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 6h
# Edited
# Report this post
# Want to test the new Magistral model on data you care about? Without GPUs and for free?
#
# Use Sheets and
# Featherless AI
# , the latest addition to
# Hugging Face
# Inference Providers!
#
# 1. Upload a dataset, import from Hugging Face, or build one from a prompt
# 2. Select Magistral-small, and run it!
# 3. Run other models and compare the results, define an LLM judge, try different tasks like summarization, extraction, etc., the possibilities are endless!
#
# Thanks to
# Featherless AI
# ,
# Hugging Face
# users can now unlock dozens of new models like Magistral. And PRO users get $2 free credits per month!
#
# Try it out:
# https://lnkd.in/dVu2f2SB
# 28
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at 🤗
# 9h
# Edited
# Report this post
# 📚✨ How (and Why) to Make GLAM Collections Ready for AI
# 🤗 aka how to turn collections into AI datasets on the
# Hugging Face
# Hub!
#
# Galleries, Libraries, Archives, and Museums hold vast digitised collections with immense potential to shape the future of AI. Preparing them for AI use isn’t just good for research – it’s also a chance to boost visibility, attract new collaborations, and create real-world impact.
#
# Join me for the next ai4lam community session, where I’ll share practical, hands-on guidance for turning collections into AI-ready datasets.
#
# As Machine Learning Librarian at Hugging Face, I see both sides of the story: AI researchers in search of quality data, and cultural institutions with incredible resources that remain underused in the AI world.
#
# In this short session, we’ll explore:
#
# - What it means to prepare collections as "AI data"
# - Why this matters: for discovery, collaboration, and institutional missions
# - How to share your data on the Hugging Face Hub
# - Practical, no-code tips to improve reuse
# - Real-world examples from GLAM institutions already doing this
#
# No technical background needed, just curiosity and a passion for collections!
#
# Registration info below 👇
# #libraries
# #archives
# #museums
# #opendata
# #ai4lam
# #collectionsasdata
# #AI
# #Europeana
# Artificial Intelligence for Libraries, Archives and Museums
# 797 followers
# 1d
# Greetings! Our June community call is Tuesday, June 17, 8:00 AM California | 11:00 AM Washington DC | 16:00 UK | 17:00 Oslo & Paris | 01:00 Sydney.
#
# Title: The Hugging Face Hub for LAM AI Datasets and Use Cases
# Presenter: Daniel van Strien, Machine Learning Librarian at Hugging Face
#
# Daniel will deliver a short practical workshop on how the LAM community can prepare data for use in machine learning projects and how machine learning and AI tools can be used to transform existing collections into data. This will include an overview of what the Hugging Face Hub is, how LAM institutions are using it to benefit from, and contribute to, the open source machine learning ecosystem and a hands on walkthrough of how you can use the Hub to share open datasets.
#
# Here's a link to the agenda:
# https://lnkd.in/dWNmxjRe
# (Don't forget to register your interest and mark yourself as attending!)
#
# Please feel free to share this announcement with interested colleagues and lists, and we look forward to seeing you on June 17!
# 2025-06-17 ai4lam Community Call
# docs.google.com
# 15
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 1d
# Report this post
# I have bittersweet news to share.
#
# Yesterday we merged a PR deprecating TensorFlow and Flax support in transformers.
#
# Going forward, we're focusing all our efforts on PyTorch to remove a lot of the bloating in the transformers library. Expect a simpler toolkit, across the board.
#
# This is not a decision we take lightly: multi-backend has been a big selling point of transformers over the years. However, we have seen our user base consolidate in PyTorch.
#
# We will keep support of TF and Flax with v4 as LTS (~mid 2026). This change marks the beginning of v5!
#
# We have heard the feedback about transformers being bloated with many layers of abstraction.
#
# With this, we expect to remove 50% of the code from the library. This will contribute to removing abstraction layers; aligned with our focus on simplification:
# https://lnkd.in/eRMMj_fm
# If you're still interested in running in Jax/TF/Keras, stay tuned, we're working with tools like MaxText/MaxDiffusion/Keras 3 to see how to use the transformers model definitions.
#
# We'll aim to continue having maximum compatibility with that ecosystem, even if outside of PyTorch.
# 1,113
# 42 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 1d
# Report this post
# So many models released past week in open AI, here’s the weekly picks 🥹
# You can find more models, datasets and demos in the link in comments 💬
#
# 📚 LLMs/Retrieval
# > Qwen released Qwen3-Reranker-4B, a text retriever that it supports 100+ languages ranking #1 on MTEB!
# > Qwen also released Qwen3-Embedding models, new embeddings that come In 600M, 4B & 8B
# > Openbmb released MiniCPM4, new family of efficient LLMs that come in different sizes for end-side devices (OS) they also released an MCP compatible version
# > Homunculus is a 12B hybrid (reasoning/chat) model distilled from Qwen3-235B by Arcee AI (OS)
#
# 🖼️💬 VLMs
# > MonkeyOCR is a new open-source state-of-the-art 3B document parser (OS)
# > Google DeepMind released desktop version of Gemma 3n
# > NVIDIA released Llama-3.1-Nemotron-Nano-VL-8B-V1, new VLM
# > MSFT released an agentic VLM for GUI control GUI-Actor-7B-Qwen2-VL based on Qwen2-VL-7B (OS)
#
# 🤖 VLAs/Robotics
# > RoboBrain2.0-7B is a new VLA with action planning with 7B and 32B sizes (OS)
# > Hugging Face released SmolVLA-Base, new vision language action model (OS)
#
# 🗣️ Audio
# > openaudio-s1-mini is a new text-to-speech model with support for various languages, offers emotional and tone markers by fishaudio
#
# ⏯️ Video Gen
# > ByteDance released ContentV-8B, new video generation model for portraits, scenes, unusual setups and more! (OS)
#
# Which one is your favorite? 👀
# …more
# 148
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 1d
# Report this post
# Brand new MCP Course has units are out, and now it's getting REAL! We've collaborated with Anthropic to dive deep into production ready and autonomous agents using MCP
#
# 🔗
# https://lnkd.in/eTuSr-Uh
# This is what the new material covers and includes:
#
# - Use Claude Code to build an autonomous PR agent
# - Integrate your agent with Slack and Github to integrate it with you Team
# - Get certified on your use case and share with the community
# - Build an autonomous PR cleanup agent on the Hugging Face hub and deploy it with spaces
#
# The material goes deep into these problems and helps you to build applications that work. We’re super excited to see what you build with it.
# 803
# 19 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Leading agents @ Hugging Face 🤗 | Polytechnique - Cambridge
# 2d
# Edited
# Report this post
# Almost didn't take time to celebrate : Smolagents just wooshed past 20k stars on Github! ⭐️
#
# Congrats to the team, especially
# Albert Villanova
# who spends lots of time improving the library, and to our community members who keep pushing it to the edge 👏
#
# It's still time to learn to use agents, head to our doc or the Agents course to get started!
# View C2PA information
# 94
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 988,866 followers
# 2d
# Report this post
# Check out the latest VJEPA 2 - SoTA world models from
# AI at Meta
# 🔥
#
# It was a pleasure collaborating with them to bring these models readily available in transformers! 🤗
# AI at Meta
# 968,477 followers
# 2d
# We’re sharing V-JEPA 2, a new world model with state-of-the-art performance in visual understanding and prediction.
#
# V-JEPA 2 is a 1.2 billion-parameter model, trained on video, that can enable zero-shot planning in robots—allowing them to plan and execute tasks in unfamiliar environments.
#
# Learn more about V-JEPA 2 ➡️
# https://lnkd.in/gNgpzpvu
# As we continue working toward our goal of achieving advanced machine intelligence (AMI), we’re also releasing three new benchmarks for evaluating how well existing models can reason about the physical world from video.
#
# Learn more and download the new benchmarks ➡️
# https://lnkd.in/gNgpzpvu
# 92
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 2d
# Report this post
# Super excited to release AutoTrain-MCP! This is an MCP server for training AI models, so you can use your AI tools to train your AI models 🤯.
#
# 🔗
# https://lnkd.in/dUuarxBP
# Use this MCP server with tools like Claude Desktop, Cursor, VSCode, ChatGPT, or Continue to do this:
#
# - Define an ML problem like Image Classification, LLM fine-tuning, Text Classification, etc.
# - Claude Desktop etc. can retrieve models and datasets from the hub using the hub MCP.
# - Training happens on a Hugging Face space, so no worries about hardware restraints.
# - Models are pushed to the hub to be used inference tools like
# Llama.cpp
# , vLLM, MLX, etc.
# - Built on top of the AutoTrain library, so it has full integration with transformers and other libraries.
#
# Everything is still under active development, but I’m super excited to hear what people build, and I’m open to contributions!
# 434
# 23 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nmistralai/Magistral-Small-2506\nUpdated\n3 days ago\n•\n7.67k\n•\n378\nopenbmb/MiniCPM4-8B\nUpdated\nabout 18 hours ago\n•\n4.55k\n•\n224\necho840/MonkeyOCR\nUpdated\n1 day ago\n•\n173\ndeepseek-ai/DeepSeek-R1-0528\nUpdated\n15 days ago\n•\n120k\n•\n1.96k\nQwen/Qwen3-Embedding-0.6B-GGUF\nUpdated\n5 days ago\n•\n16.4k\n•\n348\nBrowse 1M+ models\nSpaces\nRunning\n8.01k\n8.01k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n1.05k\n1.05k\nChatterbox TTS\n🍿\nExpressive Zeroshot TTS\nRunning\non\nZero\n679\n679\nWan2.1 Fast\n🎥\nTurn static images into animated videos\nRunning\n157\n157\nSheets\n🗂\nConvert ideas into structured datasets\nRunning\n131\n131\nAI Marketing Content Generator\n🎨\nAn AI-powered tool made for content creators and marketers\nBrowse 400k+ applications\nDatasets\nnvidia/Nemotron-Personas\nUpdated\n4 days ago\n•\n5.64k\n•\n84\nopen-thoughts/OpenThoughts3-1.2M\nUpdated\n4 days ago\n•\n13.7k\n•\n100\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n22.6k\n•\n7.92k\ninstitutional/institutional-books-1.0\nUpdated\n2 days ago\n•\n869\n•\n36\na-m-team/AM-DeepSeek-R1-0528-Distilled\nUpdated\n4 days ago\n•\n5.47k\n•\n64\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n765 models\n•\n3.43k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.17k models\n•\n6.41k followers\nAmazon\ncompany\n•\n20 models\n•\n3.23k followers\nGoogle\ncompany\n•\n999 models\n•\n16.5k followers\nIntel\ncompany\n•\n232 models\n•\n2.63k followers\nMicrosoft\ncompany\n•\n390 models\n•\n12.9k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n162 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n296 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n145,565\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,343\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,306\nSafe way to store/distribute neural network weights\nHub Python Library\n2,681\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,794\nFast tokenizers optimized for research & production\nTRL\n14,163\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,796\nState-of-the-art ML running directly in your browser\nsmolagents\n20,107\nSmol library to build great agents in Python\nPEFT\n18,760\nParameter-efficient finetuning for large language models\nDatasets\n20,267\nAccess & share datasets for an ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ## About Us
# **Hugging Face** is more than a company; it's an AI community passionately devoted to building the future of machine learning. Our mission is to democratize access to top-tier machine learning tools, enabling innovation and collaboration among a vibrant community of researchers, developers, and companies.
#
# ## Our Platform
# Hugging Face offers an unparalleled platform where the machine learning community collaborates on models, datasets, and applications. With over **1 million models** and **250,000 datasets**, users can explore, build, and share a myriad of AI-powered applications.
#
# ### Key Features:
# - **Models**: Access trending models such as **Magistral-Small** and **MiniCPM4-8B**.
# - **Datasets**: Discover extensive datasets including **OpenThoughts** and **Nanonets**.
# - **Spaces**: Run and deploy applications effortlessly with features like **DeepSite** for app generation and **Chatterbox TTS** for text-to-speech capabilities.
#
# ### Enterprise Solutions
# For larger teams, we provide paid compute solutions and enterprise-grade security, including features like Single Sign-On, priority support, and access to private datasets. Plans start from **$20/user/month**.
#
# ## Our Customers
# Join over **50,000 organizations** using Hugging Face, which include industry giants such as:
# - **Meta**
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **Intel**
#
# Our diverse customer base underscores our platform's reliability and significance in the field of machine learning.
#
# ## Company Culture
# At Hugging Face, we believe in a collaborative and inclusive environment. Our team of **215 members** fosters a culture of innovation, encouraging contributions from both experienced and budding machine learning enthusiasts. We welcome everyone to participate in shaping the future of AI, one commit at a time.
#
# ## Careers
# Join our mission to democratize machine learning! Hugging Face is always on the lookout for passionate individuals interested in contributing to cutting-edge AI research and tools. Explore job openings and become part of an exciting team that’s shaping technological advancement.
#
# ## Get In Touch
# Want to learn more or embark on your journey with Hugging Face? Visit us at [huggingface.co](https://huggingface.co) and explore our rich offerings in models, datasets, and opportunities to collaborate.
#
# ---
# **Contact Us:**
# - **Email**: [contact@huggingface.co](mailto:contact@huggingface.co)
# - **Follow us**: [Twitter](https://twitter.com/huggingface) | [GitHub](https://github.com/huggingface) | [LinkedIn](https://linkedin.com/company/huggingface)
#
# **Let's build the future of AI together!**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co/'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face - The AI Community Building the Future
#
# Welcome to Hugging Face, the leading platform where the machine learning community collaborates on innovative models, datasets, and applications. Our mission is to advance the field of AI through community-driven contributions and open-source resources, empowering developers and organizations worldwide.
#
# ## Why Choose Hugging Face?
#
# ### Unmatched Collaboration
# - **Community-Driven**: Over 50,000 organizations, including industry giants like Google, Microsoft, Amazon, and Grammarly, utilize our platform to develop and share machine learning tools.
# - **Extensive Library**: Gain access to 1M+ models and 250k+ datasets to accelerate your AI projects. Explore various modalities, including text, image, video, audio, and 3D.
#
# ### Cutting-Edge Technology
# - **Open Source Excellence**: Engage with advanced tools like Transformers, Diffusers, and Tokenizers—crafted for PyTorch, TensorFlow, and JAX.
# - **AI Applications**: Leverage innovative applications to generate content, convert ideas into structured datasets, and enhance your ML capabilities.
#
# ### Enterprise Solutions
# - **Scalable Compute Options**: Starting at just $0.60/hour for GPU access, our Compute services simplify deployment on optimized Inference Endpoints.
# - **Secure Framework**: With enterprise-grade security and dedicated support, our Enterprise offerings provide peace of mind for teams looking to innovate responsibly.
#
# ## Company Culture
#
# At Hugging Face, we believe in fostering a vibrant and inclusive company culture built on collaboration and creativity. Our team thrives in an environment where diversity of thought is encouraged, and every idea is valued. We are passionate about machine learning and are committed to giving back to the community through open-source initiatives.
#
# ## Careers at Hugging Face
#
# We are always on the lookout for talented individuals who share our vision of advancing the AI community. If you’re eager to learn, innovate, and collaborate on groundbreaking technology, consider joining us. Check our [Jobs page](#) for current openings and discover how you can contribute to the future of AI.
#
# ## Connect With Us
#
# - **Website**: [huggingface.co](https://huggingface.co)
# - **Twitter**: [@huggingface](https://twitter.com/huggingface)
# - **LinkedIn**: [Hugging Face on LinkedIn](https://linkedin.com/company/huggingface)
# - **Community Forum**: Join discussions with fellow developers and share insights.
#
# Join us at Hugging Face and be part of the community that's shaping the

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
